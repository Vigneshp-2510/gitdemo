# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([1,250])
plt.plot(x,y)
plt.show()

# %%
x=np.array([0,7])
y=np.array([1,250])
plt.plot(x,y,'*')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10,20,100])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10,20,100])
plt.plot(ypoints,marker='o',ms=10,mec='#4CAF50',mfc='#4CAF50',c='r',lw=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65c96da30138> in <module>
# ----> 1 ypoints = np.array([3, 8, 1, 10,20,100])
#       2 plt.plot(ypoints,marker='o',ms=10,mec='#4CAF50',mfc='#4CAF50',c='r',lw=2)
#       3 plt.show()
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(y1,c='r',marker='o',mec='y')
plt.plot(y2,marker='o',mec='y')

plt.xlabel("Number",fontdict = font1)
plt.ylabel("Percentage",fontdict = font1)
plt.title('sample data',fontdict = font2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(y1,c='r',marker='o',mec='y')
plt.plot(y2,marker='o',mec='y')

plt.xlabel("Number",fontdict = font1)
plt.ylabel("Percentage",fontdict = font1)
plt.title('sample data',fontdict = font2,loc='left')
# plt.grid(axis='y')
# plt.grid(axis='x')
plt.grid()
plt.grid(color = 'green', linestyle = '--', linewidth = 1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([0, 8, 1, 10])
y2 = np.array([3, 2, 7, 11])
plt.subplot(1,2,1)
plt.plot(y1,y2)
plt.title("title1")

x1 = np.array([0, 7, 7, 10])
x2 = np.array([6, 2, 7, 11])
plt.subplot(1,2,2)
plt.plot(x1,x2)
plt.title("title2")

plt.suptitle("MY SHOP")
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y,c='r')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)


x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.3)

plt.show()
